# %%
#start with small list, then try with config then try with large config
from google_images_download import google_images_download

# %%
response = google_images_download.googleimagesdownload()

# %%
"keywords": "amaranth,asiatic dayflower, beebalm", "bergamot","black nightshade","black raspberry","burdock","cattail",
    "chickweed","chicory","common mallow","cow parsnip"
            "limit": 5,

# %%
arguments = {"keywords":"amaranth,asiatic_dayflower,beebalm,bergamot,burdock,chickweed,chicory,common_mallow, \n
             cow_parsnip,curly_dock,currant,dandelion,daylily,elderberry,epazote,evening primrose, \n
             false solomon's seal, field garlic, frangrant sumac, garlic mustard,goutweed,greenbrier,hawthorn,\n
             henbit,honeywort,hopniss,jerusalem artichoke, juneberry, jewelewee, juniper, lady's thumb,lamb's quarters, mayapple,\n
             meliot, milkweed, mugwort, new england aster, nettle, oxeye daisy, parsnip, peppergrass, pickerelweed, pineappleweed,\n
             plantain, pokeweed, purslane, quickweed, salsify, saltbush, sheep sorrel, shepherd's purse, shiso, silverberry, \n
             sow thistle, spicebush, sumac, thistle, trout lily, wapato, watercress, queen anne's lace, wild ginger, wineberry,\n
             wintergreen, wood sorrel, yarow","limit":100,"print_urls":True}

# %%
paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = amaranth
# Evaluating...
# Starting Download...
# Image URL: https://www.adaptiveseeds.com/wp-content/uploads/2017/12/amaranth-copperhead-5.jpg
# Completed Image ====> 1. amaranth-copperhead-5.jpg
# Image URL: https://media.mercola.com/assets/images/foodfacts/amaranth-nutrition-facts.jpg
# Completed Image ====> 2. amaranth-nutrition-facts.jpg
# Image URL: http://www.southernexposure.com/images/large/amaranth-plainsman_LRG.jpg
# Completed Image ====> 3. amaranth-plainsman_lrg.jpg
# Image URL: https://www.adaptiveseeds.com/wp-content/uploads/2015/01/p-9940-amaranth_sunset_goldilocks2.jpg
# Completed Image ====> 4. p-9940-amaranth_sunset_goldilocks2.jpg
# Image URL: https://1rxbfb2hflyo2jt6jd3f6sjr-wpengine.netdna-ssl.com/wp-content/uploads/2014/11/MU551-3.jpg
# Completed Image ====> 5. mu551-3.jpg
# Image URL: http://cdn3.volusion.com/aueds.gjavs/v/vspfiles/photos/620-2.jpg?1515224926
# Completed Image ====> 6. 620-2.jpg
# ...

# %%
#want a dataframe of images class, class label and image name
# !ls downloads/
# Out:
#   chickweed            henbit                queen anne's lace
#   elderberry           honeywort             quickweed
#   goutweed             hopniss               salsify
#  asiatic dayflower     jerusalem artichoke   saltbush
#  beebalm               jewelewee             sheep sorrel
#  bergamot              juneberry             shepherd's purse
#  burdock               juniper               shiso
#  chicory               lady's thumb          silverberry
#  common mallow         mayapple              sow thistle
#  cow parsnip           meliot                spicebush
#  curly dock            milkweed              sumac
#  currant               mugwort               thistle
#  dandelion             nettle                trout lily
#  daylily               new england aster     wapato
#  epazote               oxeye daisy           watercress
#  evening primrose      parsnip               wild ginger
#  false solomon's seal  peppergrass           wineberry
# ...

# %%
#each label has its own folder
labels =["amaranth", "asiatic dayflower", "beebalm", "bergamot", "burdock,  chickweed", "chicory", "common mallow",
         "cow parsnip", "curly dock", "currant", "dandelion", "daylily,  elderberry", "epazote", "evening primrose",
         "false solomon's seal", "field garlic", "frangrant sumac", "garlic mustard,  goutweed", "greenbrier",
         "hawthorn", "henbit", "honeywort", "hopniss", "jerusalem artichoke", "juneberry", "jewelewee", "juniper",
         "lady's thumb,lamb's quarters", "mayapple", "meliot", "milkweed", "mugwort", "new england aster", "nettle", 
         "oxeye daisy", "parsnip", "peppergrass", "pickerelweed", "pineappleweed", "plantain", "pokeweed", "purslane",
         "quickweed", "salsify", "saltbush", "sheep sorrel", "shepherd's purse", "shiso", "silverberry", "sow thistle",
         "spicebush", "sumac", "thistle", "trout lily", "wapato", "watercress", "queen anne's lace", "wild ginger",
         "wineberry", "wintergreen", "wood sorrel", "yarow"]

# %%
len(labels) #too many classes?
# Out:
# 62

# %%
import pandas as pd
df_plants = pd.DataFrame()

# %%
df_plants['labels'] = labels

# %%
df_plants.reset_index(inplace = True)

# %%
df_plants.columns = [['class_label','class_name']]

# %%
import matplotlib.pyplot as plt
from skimage import io as skio

# %%
#look at some examples, may have to re-name folders and file names if they have spaces in them
original_img = skio.imread(f'downloads/ burdock/1. burdock-basal-rosette.jpg')

# %%
plt.imshow(original_img)

# %%
#misspelled melilot so re-do that one
arguments = {"keywords":"melilot","limit":100,"print_urls":True}
paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = melilot
# Evaluating...
# Starting Download...
# Image URL: http://www.wildflowersofireland.net/image_uploads/flowers/Melilot-Ribbed-1.jpg
# Completed Image ====> 1. melilot-ribbed-1.jpg
# Image URL: https://cdn5.fermedesaintemarthe.com/I-Autre-22199_1200x1200-melilot-officinal-ab.net.jpg
# Completed Image ====> 2. i-autre-22199_1200x1200-melilot-officinal-ab.net.jpg
# Image URL: https://thecompleteherbalguide.com/wp-content/uploads/2017/07/Melilotus-Flower.jpg
# Completed Image ====> 3. melilotus-flower.jpg
# Image URL: https://previews.123rf.com/images/13smile/13smile1607/13smile160700108/60305712-melilotus-officinalis-known-as-yellow-sweet-clover-yellow-melilot-ribbed-melilot-common-melilot-in-a.jpg
# Completed Image ====> 4. 60305712-melilotus-officinalis-known-as-yellow-sweet-clover-yellow-melilot-ribbed-melilot-common-melilot-in-a.jpg
# ...

# %%
#this library adds "1. " etc. to each image per category.
import glob

import os
from glob import iglob

rootdir_glob = 'edible_plants/**/*' # Note the added asterisks
# This will return absolute paths
file_list = [f for f in iglob('**/*', recursive=True) if os.path.isfile(f)]

# %%
test = file_list[1]

# %%
head, tail = os.path.split(test)

# %%
head.split(' ')[-1]
# Out:
# 'chickweed'

# %%
file_class_dict = {}

# %%
for i in file_list[1:]:
    head, tail = os.path.split(i)

# %%
# !gsutil -q -m cp -r edible_plants/* gs://ableto-datateam-rnd/datasets/edible_plants
# Out:
# Updates are available for some Cloud SDK components.  To install them,
# please run:
#   $ gcloud components update
#
# ^C

# %%
# !gsutil -q -m cp -r edible_plants/* gs://ableto-datateam-rnd/datasets/edible_plants
# Out:
# ^C

# %%
# !gsutil -q -m cp -r edible_plants gs://ableto-datateam-rnd/datasets
